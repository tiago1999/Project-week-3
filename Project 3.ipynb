# %%
from googleapiclient.discovery import build
import pandas as pd 

user_input=input()

## connecting to API
api_key='AIzaSyBrJG3R5SMOyl1Mg-7gKHFpqfUITMDAYmw'

youtube=build('youtube', 'v3', developerKey=api_key)


## ww2 top 6c videos request
request = youtube.search().list(
    part='snippet',
    maxResults=6,
    q = user_input
)
response = request.execute()
response
##print(user_input)
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'FutglYADI8EKqhrcIGmn4UwX91w',
#  'nextPageToken': 'CAYQAA',
#  'regionCode': 'PT',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 6},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'glPlntFKlE50rw6FPqLU6dqTovQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'QWgtu19l3n0'},
#    'snippet': {'publishedAt': '2022-07-19T14:00:20Z',
#     'channelId': 'UC4qa5EroJxnQM6Sng9WhgsQ',
#     'title': 'Pumping Surf in Nicaragua!',
#     'description': 'Is this the Code Red 2 Swell hitting Nicaragua? This is the dream. Using my ability to surf & create memorable content for people ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QWgtu19l3n0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QWgtu19l3n0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QWgtu19l3n0/hqdefault.jpg',
# ...

# %%
# creating list and dict of title and description of ww2 

title_list = []
description = []
videoID=[]

for title in response['items']:
   title_list.append( title['snippet']['title'])
   description.append( title['snippet']['description'])
   videoID.append( title['id']['videoId'])


title_description = {}

dictionary = {key: val for key, val in zip(title_list, description)}
print(videoID)
# Out:
# ['QWgtu19l3n0', 'ma67yOdMQfs', 'grBmKQ3MpaQ', 'pmlzdeZuAk8', 'T3Vxpp9pT4U', 'eo0K6uc1BS8']

# %%
## GOOGLE BOOKS
google_key='AIzaSyBGu8FOQ_34lF0Uw-m5EDGuTeIlFcLQH3U'
q
fetch(`https://www.googleapis.com/books/v1/volumes?q=search-terms&key=AIzaSyBGu8FOQ_34lF0Uw-m5EDGuTeIlFcLQH3U)
  .then(response => response.json())
  .then(result => {
this.setState({ books: result.items})
})}

# %%
import requests

# %%
google_key='AIzaSyBGu8FOQ_34lF0Uw-m5EDGuTeIlFcLQH3U'
url = 'https://www.googleapis.com/books/v1/volumes?q=word_war_II&key=AIzaSyBGu8FOQ_34lF0Uw-m5EDGuTeIlFcLQH3U'

url = 'https://www.googleapis.com/books/v1/volumes?q=word_war_II&key=AIzaSyBGu8FOQ_34lF0Uw-m5EDGuTeIlFcLQH3U'

params={'search-terms': 'world war II',
'apikey': google_key}

response = requests.get(url=url2, params=params)

response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 441,
#  'items': [{'kind': 'books#volume',
#    'id': 'tChPtAEACAAJ',
#    'etag': 'KBnb4ZBAmwg',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/tChPtAEACAAJ',
#    'volumeInfo': {'title': 'Word War I & Word War II',
#     'authors': ['Rebecca Rass'],
#     'publishedDate': '1974',
#     'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'OCLC:994611640'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 41,
#     'printType': 'BOOK',
#     'categories': ['Hebrew poetry'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'language': 'en',
#     'previewLink': 'http://books.google.pt/books?id=tChPtAEACAAJ&dq=word_war_II&hl=&cd=1&source=gbs_api',
# ...

# %%
##input()

videoID=[]
string1='https://www.youtube.com/watch?v='
string2='QWgtu19l3n0'


youtubeurl=string1+string2
print(youtubeurl)
# Out:
# https://www.youtube.com/watch?v=QWgtu19l3n0
